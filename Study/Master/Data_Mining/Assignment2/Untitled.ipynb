# %%
import pandas as pd

# %%
data = pd.read_csv('nodes.csv')
data.info()

# %%
df = data[["video_title", "video_description", "video_thumbnail"]]

# %%
df.sample(50)
# Out:
#                                             video_title  \
# 1091  Ureter, Urinary Bladder and Male/Female Urethr...
# 846      Doctor Mike & Nephew Mini Vlog | Pizza MUKBANG
# 53    Biomimicry: definition & examples (explained w...
# 566                         How to Make an SDS-PAGE gel
# 863   Doctor Mike and Mortician React To “Six Feet U...
# 1559  Innate and adaptive immunity | immune system o...
# 697               Steps of histological study: fixation
# 2420  Mitochondria control of physiology and disease...
# 2431  Detection with VECTASTAIN ELITE ABC Kit from V...
# 1428                Richard Branson: Talking Management
# 1845  Samurai Sword Master Rates 10 Japanese Sword S...
# 511                            EXPERIMENT: LAVA vs POOL
# 384   Should you take Vitamin C and Vitamin D to fig...
# 1931  Accent Expert Breaks Down 6 Fictional Language...
# 1300  Explaining The Tree of Life | #Attenborough90 ...
# 1509                                    GPCR Signalling
# ...
